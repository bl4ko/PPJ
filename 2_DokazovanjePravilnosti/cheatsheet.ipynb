# %% [markdown]
# # Dokazovanje pravilnosti
#
# `Zancna invarianta I(y)`: pogoj, ki je vedno resnicen pred, za in po vsaki iteraciji zanke.
#
# `Popolna pravilnost`: program se zakljuci

# %% [markdown]
# ### naloga pravilnost 1
#
# Pojasni, kaj o programu `P` pove izjava
#
# ```
# [ true ]
# P
# [ false ]
# ```
#
# Program `P` se ustavi, po koncu izvajanja pa velja `false`. Tak program ne obstaja

# %% [markdown]
# ### Naloga pravilnost II
#
# Dokaži, delno pravilnost programa:
#
# ```
# { x > 2 }
# y := x + 1
# if x > y then
#     z := x*x - y*y
# else
#     z := y*y - x*x
# end
# { 1 ≤ z }
# ```
#
# Rešitev:
# ```
# { x > 2 }
# y := x + 1
# { x > 2 ∧ y = x + 1 }
# if x > y then
#     { x > 2 ∧ y = x + 1 ∧ x > y }
#     z := x*x - y*y
#     { z = x² - y² ∧ x > 2 ∧ y = x + 1 ∧ x > y } # A
# else
#     { x ≤ y ∧ x > 2 ∧ y = x + 1 }
#     z := y*y - x*x
#     { z = y² - x² ∧ x ≤ y ∧ x > 2 ∧ y = x + 1 } # B
# end
# # Velja: (A ⇒ 1 ≤ z) ∧ (B ⇒ 1 ≤ z), ker A ⇔ false
# { 1 ≤ z }
# ```

# %% [markdown]
# ### Naloga pravilnost III
#
# Dokaži delno pravilnost programa:
#
# ```
# { 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
# if x < y then
#   if x < z then
#     m := x
#   else
#     m := z
#   end
# else
#   if y <= z then
#      m := y
#   else
#      m := z
#   end
# end
# { 0 ≤ m ≤ x }
# ```
#
#
# Rešitev
# ```
# { 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
# if x < y then
#   { x < y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#   if x < z then
#     { x < z ∧ x < y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#     m := x
#     { m = x ∧ x < z ∧ x < y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#     { 0 ≤ m ≤ x}
#   else
#     { z ≤ x ∧ x < y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#     m := z
#     { m = z ∧ z ≤ x ∧ x < y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#     { 0 ≤ m ≤ x}
#   end
#   { 0 ≤ m ≤ x}
# else
#   { x > y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#   if y <= z then
#      { y ≤ z ∧ x > y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#      m := y
#      { m = y ∧ y ≤ z ∧ x ≥ y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#      { 0 ≤ m ≤ x}
#   else
#      { y > z ∧ x > y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#      m := z
#      { m = z ∧ y > z ∧ x ≥ y ∧ 0 ≤ x ∧ 0 ≤ y ∧ 0 ≤ z }
#      { 0 ≤ m ≤ x}
#   end
#   { 0 ≤ m ≤ x}
# end
# { 0 ≤ m ≤ x }
# ```

# %% [markdown]
# ### Naloga pravilnost IV
#
# Dokažite delno pravilnost programa:
#
# ```
# { 0 < a ∧ 0 < b }
# k := 0
# while not (a * k = b) do
#   k := k + 1
# done
# { b = a * k }
# ```
#
# Ali velja tudi popolna pravilnost? (Se pravi, da `{ ⋯ }` nadomestimo z `[ ⋯ ]`.) Odgovor utemeljite.
#
# Rešitev:
#
# Negacija zančnega pogoja je enaka končnemu pogoju: ce se zanka izteče, mora veljati končni pogoj
#
# ```
# { 0 < a ∧ 0 < b }
# k := 0
# while not (a * k = b) do
#   k := k + 1
# done
# { a * k = b }
# ```
#
# Popolna pravilnost ne velja; program se zacikla, ce `a` ne deli `b`

# %% [markdown]
# ### Naloga pravilnost V
#
# Dokažite popolno pravilnost programa:
#
# ```
# [ 0 < a ∧ 0 < b ]
# k := 0
# while a * k < b do
#   k := k + 1
# done
# [ a * (k - 1) < b ≤ a * k ]
# ```
#
# Rešitev:
#
# - naprej pokažemo delno pravilnost
#
#     ```
#     { 0 < a ∧ 0 < b }
#     k := 0
#     { 0 < a ∧ 0 < b ∧ k = 0 }
#     { a * (k - 1) < b }  # zančna invarianta
#     while a * k < b do
#     { a * (k - 1) < b ∧ a * k < b }
#     { a * (k + 1 - 2) < b ∧ a * (k + 1 - 1) < b }
#     k := k + 1
#     { a * (k - 2) < b ∧ a * (k - 1) < b }
#     { a * (k - 1) < b }  # po tem, ko se izvede telo zanke, invarianta še zmeraj velja
#     done
#     { a * (k - 1) < b ∧ ¬(a * k < b) }
#     { a * (k - 1) < b ≤ a * k }
#     ```
#
#
# - za popolno pravilnost pokažemo, da se količina `d = b -k*a` (in je navzdol omejena z zančnim pogojem):
#
#     ```
#     while a * k < b do
#     { 0 < a ∧ d = b - k*a }
#     { 0 < a ∧ d - a = b - (k+1)*a }
#     k := k + 1
#     { 0 < a ∧ d - a = b - k*a }  # d - a < d
#     done
#     ```
